# %%
import pandas as pd

# %% [markdown]
# ### Order is Accuracy, TPR, FPR, Precision

# %%
# Predicting whether there is a delay

baseline = [0.6371, 0, 0, 0]
logreg = [0.6630, 0.2534, 0.1051, 0.5769]
lda = [0.6638, 0.2604, 0.1079, 0.5772]
decision_tree_classifier_cv = [0.6721, 0.3160, 0.1263, 0.5860]
random_forest_classifier_cv = [0.6872, 0.3610, 0.1282, 0.6144]

comparison_data = {'Baseline': baseline,
                   'Logistic Regression': logreg,
                   'Linear Discriminant Analysis': lda,
                   'Decision Tree Classifier with CV': decision_tree_classifier_cv,
                   'Random Forest Classifier with CV': random_forest_classifier_cv}

comparison_table = pd.DataFrame(data=comparison_data, index=['Accuracy', 'TPR', 'FPR','PRE']).transpose()
comparison_table.style.set_properties(**{'font-size': '12pt',}).set_table_styles([{'selector': 'th', 'props': [('font-size', '10pt')]}])
comparison_table
# Out:
#                                   Accuracy     TPR     FPR     PRE
# Baseline                            0.6371  0.0000  0.0000  0.0000
# Logistic Regression                 0.6630  0.2534  0.1051  0.5769
# Linear Discriminant Analysis        0.6638  0.2604  0.1079  0.5772
# Decision Tree Classifier with CV    0.6721  0.3160  0.1263  0.5860
# Random Forest Classifier with CV    0.6872  0.3610  0.1282  0.6144

# %%
# Predicting whether the delay will be long (more than 15 minutes long)

baseline = [0.8259, 0, 0, 0]
logreg = [0.8256, 0, 0, 0]
lda = [0.8255, 0.0000, 0.0001, 0.0000]
decision_tree_classifier_cv = [0.8262, 0.0143, 0.0023, 0.5670]
random_forest_classifier_cv = [0.8267, 0.0369, 0.0064, 0.5483]

comparison_data = {'Baseline': baseline,
                   'Logistic Regression': logreg,
                   'Linear Discriminant Analysis': lda,
                   'Decision Tree Classifier with CV': decision_tree_classifier_cv,
                   'Random Forest Classifier with CV': random_forest_classifier_cv}

comparison_table = pd.DataFrame(data=comparison_data, index=['Accuracy', 'TPR', 'FPR','PRE']).transpose()
comparison_table.style.set_properties(**{'font-size': '12pt',}).set_table_styles([{'selector': 'th', 'props': [('font-size', '10pt')]}])
comparison_table
# Out:
#                                   Accuracy     TPR     FPR     PRE
# Baseline                            0.8259  0.0000  0.0000  0.0000
# Logistic Regression                 0.8256  0.0000  0.0000  0.0000
# Linear Discriminant Analysis        0.8255  0.0000  0.0001  0.0000
# Decision Tree Classifier with CV    0.8262  0.0143  0.0023  0.5670
# Random Forest Classifier with CV    0.8267  0.0369  0.0064  0.5483
